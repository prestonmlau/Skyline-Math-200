# %% [markdown]
# <a href="https://colab.research.google.com/github/prestonmlau/Skyline-Math-200/blob/main/PL_Copy_of_Python_Notebook_Setup_by_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Research Question # __ : Include question here Is there an association between serving in the military and having trouble
# sleeping?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://drive.google.com/file/d/1IbHzUMYKFBkmW3TIvryP7XJlW-WkmGEw/view?usp=sharing'
path= 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)
df.head()
# Out:
#        AID  BIO_SEX        agew1 IMONTH4 IDAY4 IYEAR4   MACNO4 INTID4  \
# 0  5710027        2
# 1  5710131        2  19.42739726       5     6   2008  2288160    160
# 2  5710317        1
# 3  5710386        1  20.43013699       5    22   2008  2288238    238
# 4  5710455        2
#
#   BIO_SEX4 VERSION4  ... H4EO5C H4EO5D H4EO5E H4EO5F H4EO5G H4EO5H H4EO5I  \
# 0                    ...
# 1        2     V5.4  ...      0      0      0      0      0      0      0
# 2                    ...
# 3        1     V5.4  ...      0      0      0      0      0      0      0
# 4                    ...
#
#   H4EO5J H4EO6 H4EO7
# 0
# 1      0     2     1
# 2
# 3      0     4     1
# 4
#
# [5 rows x 976 columns]

# %%
pip install researchpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#import researchPy

# %%
import researchpy as rp

# %% [markdown]
# Codebook 1

# %% [markdown]
# ![Screen Shot 2023-04-30 at 11.58.19 PM.png](data:image/png;base64,...)

# %%
#Manage data for variable 1
df['H4MI1'].value_counts()
# Out:
# 0    4763
#      1390
# 1     351
# Name: H4MI1, dtype: int64

# %%
df['serve_military']=df['H4MI1']
df['serve_military'].value_counts()
# Out:
# 0    4763
#      1390
# 1     351
# Name: serve_military, dtype: int64

# %%
df['serve_military']=df['serve_military'].loc[df['serve_military']!=' ']
df['serve_military'].value_counts()
# Out:
# 0    4763
# 1     351
# Name: serve_military, dtype: int64

# %%
df['serve_military'].replace(['0','1'], ['no','yes',],inplace=True)
df['serve_military'].value_counts()
# Out:
# no     4763
# yes     351
# Name: serve_military, dtype: int64

# %%
rp.summary_cat(df['serve_military'])
# Out:
#          Variable Outcome  Count  Percent
# 0  serve_military      no   4763    93.14
# 1                     yes    351     6.86

# %%
#Graphs and tables or statistics
df['serve_military'].value_counts(normalize=True).plot(kind='pie')
# Out:
# <Axes: ylabel='serve_military'>

# %%
df['serve_military'].value_counts(normalize=True).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Codebook 2:

# %% [markdown]
# ![Screen Shot 2023-05-01 at 12.03.57 AM.png](data:image/png;base64,...)

# %%
#Manage data for variable 1
df['H4SP5'].value_counts()
# Out:
# 0    2400
#      1390
# 1     950
# 2     911
# 4     411
# 3     395
# 5      46
# 8       1
# Name: H4SP5, dtype: int64

# %%
df['trouble_sleeping'] = df['H4SP5']
df['trouble_sleeping'].value_counts()
# Out:
# 0    2400
#      1390
# 1     950
# 2     911
# 4     411
# 3     395
# 5      46
# 8       1
# Name: trouble_sleeping, dtype: int64

# %%
df['trouble_sleeping'] = df['trouble_sleeping'].loc[ df['trouble_sleeping'] !=' ']
df['trouble_sleeping'].value_counts()
# Out:
# 0    2400
# 1     950
# 2     911
# 4     411
# 3     395
# 5      46
# 8       1
# Name: trouble_sleeping, dtype: int64

# %%
df['trouble_sleeping']=df['trouble_sleeping'].loc[df['trouble_sleeping']!='5']
df['trouble_sleeping']=df['trouble_sleeping'].loc[df['trouble_sleeping']!='8']
df['trouble_sleeping'].value_counts()
# Out:
# 0    2400
# 1     950
# 2     911
# 4     411
# 3     395
# Name: trouble_sleeping, dtype: int64

# %%
df['trouble_sleeping'].replace(['0','1','2','3','4'],['never in the past four weeks','less than once a week','1 or 2 times a week','3 or 4 times a week','5 or more times a week'],inplace=True)
df['trouble_sleeping'].value_counts()
# Out:
# never in the past four weeks    2400
# less than once a week            950
# 1 or 2 times a week              911
# 5 or more times a week           411
# 3 or 4 times a week              395
# Name: trouble_sleeping, dtype: int64

# %%
rp.summary_cat(df['trouble_sleeping'])
# Out:
#            Variable                       Outcome  Count  Percent
# 0  trouble_sleeping  never in the past four weeks   2400    47.37
# 1                           less than once a week    950    18.75
# 2                             1 or 2 times a week    911    17.98
# 3                          5 or more times a week    411     8.11
# 4                             3 or 4 times a week    395     7.80

# %%
#Graphs and tables or statistics

# %%
df['trouble_sleeping'].value_counts().plot(kind ='pie')
# Out:
# <Axes: ylabel='trouble_sleeping'>

# %%
df['trouble_sleeping'].value_counts(normalize = True).plot(kind ='bar')
# Out:
# <Axes: >

# %% [markdown]
# Codebook 3

# %% [markdown]
# ![Screen Shot 2023-05-01 at 12.52.26 PM.png](data:image/png;base64,...)

# %%
#Manage data for variable 3
df['H4GH1'].value_counts()
# Out:
# 2    1963
# 3    1683
#      1390
# 1     979
# 4     434
# 5      55
# Name: H4GH1, dtype: int64

# %%
df['health_status']=df['H4GH1']
df['health_status'].value_counts()
# Out:
# 2    1963
# 3    1683
#      1390
# 1     979
# 4     434
# 5      55
# Name: health_status, dtype: int64

# %%
df['health_status']=df['health_status'].loc[df['health_status']!=' ']
df['health_status'].value_counts()
# Out:
# 2    1963
# 3    1683
# 1     979
# 4     434
# 5      55
# Name: health_status, dtype: int64

# %%
df['health_status'].replace(['1','2','3','4','5'], ['excellent','very good','good','fair','poor'],inplace=True)
df['health_status'].value_counts()
# Out:
# very good    1963
# good         1683
# excellent     979
# fair          434
# poor           55
# Name: health_status, dtype: int64

# %%
rp.summary_cat(df['health_status'])
# Out:
#         Variable    Outcome  Count  Percent
# 0  health_status  very good   1963    38.38
# 1                      good   1683    32.91
# 2                 excellent    979    19.14
# 3                      fair    434     8.49
# 4                      poor     55     1.08

# %%
#Graphs and tables or statistics
df['health_status'].value_counts(normalize=True).plot(kind='pie')
# Out:
# <Axes: ylabel='health_status'>

# %%
df['health_status'].value_counts(normalize=True).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Codebook 4

# %% [markdown]
# ![Screen Shot 2023-05-01 at 12.53.30 PM.png](data:image/png;base64,...)

# %%
df['H4WS4'].value_counts()
# Out:
# 3     2319
#       1390
# 2     1121
# 4      861
# 5      620
# 1      145
# 95      46
# 96       1
# 98       1
# Name: H4WS4, dtype: int64

# %%
df['close_friends'] = df['H4WS4']
df['close_friends'].value_counts()
# Out:
# 3     2319
#       1390
# 2     1121
# 4      861
# 5      620
# 1      145
# 95      46
# 96       1
# 98       1
# Name: close_friends, dtype: int64

# %%
df['close_friends'] = df['close_friends'].loc[ df['close_friends'] !=' ']
df['close_friends'].value_counts()
# Out:
# 3     2319
# 2     1121
# 4      861
# 5      620
# 1      145
# 95      46
# 96       1
# 98       1
# Name: close_friends, dtype: int64

# %%
df['close_friends']=df['close_friends'].loc[df['close_friends']!='95']
df['close_friends']=df['close_friends'].loc[df['close_friends']!='96']
df['close_friends']=df['close_friends'].loc[df['close_friends']!='98']
df['close_friends'].value_counts()
# Out:
# 3    2319
# 2    1121
# 4     861
# 5     620
# 1     145
# Name: close_friends, dtype: int64

# %%
df['close_friends'].replace(['1','2','3','4','5'],['none','1 or 2 friends','3 to 5 friends','6 to 9 friends','10 or more friends'],inplace=True)
df['close_friends'].value_counts()
# Out:
# 3 to 5 friends        2319
# 1 or 2 friends        1121
# 6 to 9 friends         861
# 10 or more friends     620
# none                   145
# Name: close_friends, dtype: int64

# %%
rp.summary_cat(df['close_friends'])
# Out:
#         Variable             Outcome  Count  Percent
# 0  close_friends      3 to 5 friends   2319    45.78
# 1                     1 or 2 friends   1121    22.13
# 2                     6 to 9 friends    861    17.00
# 3                 10 or more friends    620    12.24
# 4                               none    145     2.86

# %%
#Graphs and tables or statistics
df['close_friends'].value_counts().plot(kind ='pie')
# Out:
# <Axes: ylabel='close_friends'>

# %%
df['close_friends'].value_counts(normalize = True).plot(kind ='bar')
# Out:
# <Axes: >
